# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_path = r"/content/drive/MyDrive/Yolov8-relu"
os.chdir(notebook_path)

# %%
# !nvidia-smi
# Out:
# Tue Apr 22 07:25:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
if not os.path.isdir("Yolov8"):
  os.makedirs("Yolov8")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fHndOQqPIDQZsuEkj3H7")
project = rf.workspace("for-testing-lfsav").project("small-object-zytwr")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to small-object-2 in yolov8:: 100%|██████████| 6450/6450 [00:51<00:00, 124.24it/s]

# %%
import torch
import torch.nn as nn  # Ensure nn is defined

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 982.4/982.4 kB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8s-relu.yaml").load("yolov8s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Transferred 355/355 items from pretrained weights

# %%
model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): ReLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s-relu.yaml pretrained=yolov8s.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
dataset_path = "/content/drive/MyDrive/Yolov8-relu/small-object-2/data.yaml"

# %%
# !yolo task=detect mode=train model=yolov8s-relu.yaml pretrained=yolov8s.pt data={dataset_path} epochs=50 imgsz=640
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Yolov8/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/Yolov8/small-object-2/test/images
# Out:
# Ultralytics 8.3.93 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-relu summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/190 /content/drive/MyDrive/Yolov8/small-object-2/test/images/0026_jpg.rf.04784bad856a2160b32e9b945669f381.jpg: 640x640 1 paperclip, 16.3ms
# image 2/190 /content/drive/MyDrive/Yolov8/small-object-2/test/images/0054_jpg.rf.2322e283002ccaa323bf73b593d8414f.jpg: 640x640 1 paperclip, 17.3ms
# image 3/190 /content/drive/MyDrive/Yolov8/small-object-2/test/images/112_jpeg.rf.9ce41c4665f8cc2926e3a5523b06ddbe.jpg: 640x640 1 lego, 16.3ms
# image 4/190 /content/drive/MyDrive/Yolov8/small-object-2/test/images/132_jpeg.rf.b16a182710028720390776986575dd95.jpg: 640x640 1 lego, 16.2ms
# image 5/190 /content/drive/MyDrive/Yolov8/small-object-2/test/images/13_jpeg.rf.9d551bd356293ef0db0468434dc37842.jpg: 640x640 1 lego, 16.2ms
# ...
