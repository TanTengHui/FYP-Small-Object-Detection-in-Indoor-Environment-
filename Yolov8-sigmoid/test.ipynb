# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_path = r"/content/drive/MyDrive/Yolov8-sigmoid"
os.chdir(notebook_path)

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fHndOQqPIDQZsuEkj3H7")
project = rf.workspace("for-testing-lfsav").project("small-object-testing")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 135.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to small-object-testing-1 in yolov8:: 100%|██████████| 6990/6990 [00:49<00:00, 141.04it/s]

# %%
import torch
import torch.nn as nn  # Ensure nn is defined

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8s-sigmoid.yaml").load("yolov8s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Transferred 355/355 items from pretrained weights

# %%
model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): Sigmoid()
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): Sigmoid()
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): Sigmoid()
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): Sigmoid()
# ...

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8s-leaky summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# PyTorch: starting from 'yolov8s-leaky.yaml' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (0.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 264.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 271.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 271.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 233.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 245.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.4s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime']
# ...

# %%
# !yolo task=detect mode=train model=yolov8s-sigmoid.yaml pretrained=yolov8s.pt data={dataset.location}/data.yaml epochs=20 imgsz=640
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
dataset_path = "/content/drive/MyDrive/Yolov8-sigmoid/small-object-2/data.yaml"

# %%
dataset_path2 = "/content/drive/MyDrive/Yolov8-sigmoid/small-object-testing-1/data.yaml"

# %%
# !yolo task=detect mode=train model=yolov8s-sigmoid.yaml pretrained=yolov8s.pt data={dataset_path} epochs=50 imgsz=640
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s-sigmoid.yaml pretrained=yolov8s.pt data={dataset_path2} epochs=50 imgsz=640
# Out:
# Transferred 355/355 items from pretrained weights
# Ultralytics 8.3.146 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os
import cv2
from ultralytics import YOLO

def process_images(input_dir, output_dir, model_path, threshold=0.25):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    model = YOLO(model_path)
    jpg_files = [f for f in os.listdir(input_dir) if f.lower().endswith(".jpg")]

    for filename in jpg_files:
        image_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        image = cv2.imread(image_path)
        if image is None:
            print(f"❌ Error: Could not read {image_path}")
            continue

        results = model(image)[0]

        if not results.boxes:
            print(f"⚠️ No objects detected in {filename}")
        else:
            for box in results.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                conf = float(box.conf[0])
                cls = int(box.cls[0])

                if conf > threshold:
                    label = f"{model.names[cls]}: {conf:.2f}"

                    # Draw bounding box
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

                    # Get text size
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    font_scale = 0.6
                    thickness = 1
                    (text_w, text_h), _ = cv2.getTextSize(label, font, font_scale, thickness)

                    # Determine label position (top or bottom of box)
                    label_y = y1 - 10 if y1 - 10 > text_h else y2 + text_h + 10

                    # Draw label background
                    cv2.rectangle(image, (x1, label_y - text_h), (x1 + text_w, label_y), (0, 255, 0), -1)
                    # Put label text
                    cv2.putText(image, label, (x1, label_y - 2), font, font_scale, (0, 0, 0), thickness)

                    # Console output
                    print(f"🔹 {filename} - Class {cls} ({model.names[cls]}), Conf: {conf:.2f}, Box: ({x1}, {y1}, {x2}, {y2})")

        cv2.imwrite(output_path, image)
        print(f"✅ Saved: {output_path}")

# %%
model_path = '/content/drive/MyDrive/Yolov8-sigmoid/runs/detect/train3/weights/best.pt'
input_directory = '/content/drive/MyDrive/Yolov8-sigmoid/preprocess'
output_directory = '/content/drive/MyDrive/Yolov8-sigmoid/processed_images/test2'

process_images(input_directory, output_directory, model_path)
# Out:
# 0: 640x640 1 dice, 1 marble, 635.5ms
# Speed: 15.0ms preprocess, 635.5ms inference, 33.2ms postprocess per image at shape (1, 3, 640, 640)
# 🔹 1747640667397.jpg - Class 3 (dice), Conf: 0.71, Box: (252, 262, 284, 287)
# 🔹 1747640667397.jpg - Class 7 (marble), Conf: 0.69, Box: (237, 239, 275, 266)
# ✅ Saved: /content/drive/MyDrive/Yolov8-sigmoid/processed_images/test2/1747640667397.jpg
#
# 0: 640x640 1 dice, 1 marble, 598.3ms
# Speed: 2.9ms preprocess, 598.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 🔹 1747640667391.jpg - Class 7 (marble), Conf: 0.70, Box: (239, 237, 277, 264)
# 🔹 1747640667391.jpg - Class 3 (dice), Conf: 0.70, Box: (253, 258, 287, 286)
# ✅ Saved: /content/drive/MyDrive/Yolov8-sigmoid/processed_images/test2/1747640667391.jpg
#
# 0: 640x640 1 dice, 1 marble, 594.3ms
# Speed: 4.2ms preprocess, 594.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 🔹 1747640667386.jpg - Class 7 (marble), Conf: 0.71, Box: (239, 235, 277, 262)
# ...
